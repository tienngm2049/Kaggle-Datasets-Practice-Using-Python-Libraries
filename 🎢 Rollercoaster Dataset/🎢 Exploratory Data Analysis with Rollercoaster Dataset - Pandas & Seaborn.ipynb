# %% [markdown]
# # 🎢 Introduction to Exploratory Data Analysis
#
# ## Step 0: Imports and Reading Data
# - Libraries
#
# - `pd.options.display.max_columns` option to set the maximum number of columns that are displayed
#
# - `%matplotlib inline` to remove plt.show()
#
# - `plt.style.use('ggplot')` to style chart

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set_theme(rc={'figure.dpi':200,'figure.figsize': (15,10)})
plt.style.use('ggplot')
pd.options.display.max_columns = 100 #

# %%
df = pd.read_csv("Dataset\coaster_db.csv")

# %% [markdown]
# ## Step 1: Data Understanding
#
# - Dataframe `shape`
#
# - `head()` and `tail()`
#
# - `dtypes`
#
# - `describe()`
#
# - `info`
#
# - `columns`

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe() # only numeric data
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %% [markdown]
# ## Step 2: Data Preperation
#
# - Dropping irrelevant columns and rows
#
# - Identifying duplicated columns
#
# - Renaming Columns
#
# - Feature Creation

# %% [markdown]
# ### 2.1 Change type and remove irrelevant columns df

# %%
df = df[['coaster_name',
    # 'Length', 'Speed',
    'Location', 'Status',
    # 'Opening date',
    #   'Type',
    'Manufacturer',
#     'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date',
#     'Opened', 
    # 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced',
        'latitude', 'longitude',
    'Type_Main',
       'opening_date_clean',
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
    #'height_value', 'height_unit',
    'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
# Example of dropping columns
# df.drop(['Opening date'], axis=1)

# %%
# turn type of df['opening_date_clean'] from object to datetime

df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])

# %%
df.dtypes
# Out:
# coaster_name                  object
# Location                      object
# Status                        object
# Manufacturer                  object
# year_introduced                int64
# latitude                     float64
# longitude                    float64
# Type_Main                     object
# opening_date_clean    datetime64[ns]
# speed_mph                    float64
# height_ft                    float64
# Inversions_clean               int64
# Gforce_clean                 float64
# dtype: object

# %% [markdown]
# ### 2.2 Rename Column
#
# - `str.title()`
#
# - `str.replace()`
#
# - `df.rename(columns={''})`

# %%
# str.title() to capitalize the first letter of each word in the column names, 
# and str.replace() to replace the space between words with an underscore. 
# df.columns = df.columns.str.title().str.replace(' ', '_')

df.columns = df.columns.str.title()

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'Latitude', 'Longitude', 'Type_Main', 'Opening_Date_Clean', 'Speed_Mph',
#        'Height_Ft', 'Inversions_Clean', 'Gforce_Clean'],
#       dtype='object')

# %%
# Rename a column

df = df.rename(columns={'Opening_Date_Clean':'Opening_Date',
                   'Inversions_Clean':'Inversions',
                   'Gforce_Clean':'Gforce'})

# %%
df.head()
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  Year_Introduced  Latitude  Longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type_Main Opening_Date  Speed_Mph  Height_Ft  Inversions  Gforce
# ...

# %% [markdown]
# ### 2.3 Handle Missing Values
#
# There are several ways to handle missing values in a dataset. The choice of method depends on the nature of the data and the specific analysis or modeling task. Here are some common approaches:
#
# 1. **Dropping missing values**: If the missing values are relatively few and randomly distributed, you can simply drop the rows or columns containing missing values. This can be done using the `dropna()` function in pandas.
#
#    ```python
#    df.dropna()  # Drop rows with any missing value
#    df.dropna(axis=1)  # Drop columns with any missing value
#    ```
#
#    However, be cautious when using this method, as dropping too many observations can lead to loss of valuable information.
#
# 2. **Imputation**: Missing values can be replaced with estimated values. Some common imputation techniques include:
#
#    - **Mean or median imputation**: Replace missing values with the mean or median of the available data for that variable.
#
#      ```python
#      df['column_name'].fillna(df['column_name'].mean(), inplace=True)
#      ```
#
#    - **Mode imputation**: Replace missing values with the mode (most frequent value) of the variable.
#
#      ```python
#      df['column_name'].fillna(df['column_name'].mode()[0], inplace=True)
#      ```
#
#    - **Forward or backward fill**: Fill missing values with the last observed value (forward fill) or the next observed value (backward fill).
#
#      ```python
#      df.fillna(method='ffill', inplace=True)  # Forward fill
#      df.fillna(method='bfill', inplace=True)  # Backward fill
#      ```
#
#    - **Interpolation**: Fill missing values by interpolating between existing values. This can be useful for time series data or data with a specific order.
#
#      ```python
#      df.interpolate(inplace=True)
#      ```
#
#    Imputation methods should be used with caution, as they introduce assumptions and may impact the distribution and relationships in the data.
#
# 3. **Indicator variables**: Create new binary variables that indicate whether a value was missing or not. This approach allows the missingness to be included as a feature in the analysis.
#
#    ```python
#    df['column_name_isnull'] = df['column_name'].isnull().astype(int)
#    ```
#
# 4. **Advanced techniques**: There are more advanced techniques available for handling missing data, such as multiple imputation or using machine learning algorithms to predict missing values based on other variables. These methods are more complex and may require additional libraries or expertise.
#
# Remember to carefully consider the nature of the missing data and the implications of each handling method for your specific analysis or modeling task.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1087 entries, 0 to 1086
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Coaster_Name     1087 non-null   object
#  1   Location         1087 non-null   object
#  2   Status           874 non-null    object
#  3   Manufacturer     1028 non-null   object
#  4   Year_Introduced  1087 non-null   int64
#  5   Latitude         812 non-null    float64
#  6   Longitude        812 non-null    float64
#  7   Type_Main        1087 non-null   object
#  8   Opening_Date     837 non-null    datetime64[ns]
#  9   Speed_Mph        937 non-null    float64
#  10  Height_Ft        171 non-null    float64
#  11  Inversions       1087 non-null   int64
#  12  Gforce           362 non-null    float64
# dtypes: datetime64[ns](1), float64(5), int64(2), object(5)
# memory usage: 110.5+ KB

# %%
# Check missing values
# df.isna().sum() is the same

df.isnull().sum()
# Out:
# Coaster_Name         0
# Location             0
# Status             213
# Manufacturer        59
# Year_Introduced      0
# Latitude           275
# Longitude          275
# Type_Main            0
# Opening_Date       250
# Speed_Mph          150
# Height_Ft          916
# Inversions           0
# Gforce             725
# dtype: int64

# %% [markdown]
# ### 2.4 Handle Duplicate Values

# %%
# True is considered a duplicate

df.duplicated().value_counts()
# Out:
# False    1087
# dtype: int64

# %%
# To drop the duplicate rows from the DataFrame, you can use the drop_duplicates() function:

df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  Year_Introduced  Latitude  Longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type_Main Opening_Date  Speed_Mph  Height_Ft  Inversions  Gforce
# ...

# %%
# Check for duplicate coaster name

df.loc[df.duplicated(subset=['Coaster_Name'])].head(5)
# Out:
#                           Coaster_Name             Location     Status  \
# 43               Crystal Beach Cyclone   Crystal Beach Park    Removed
# 60                         Derby Racer         Revere Beach    Removed
# 61         Blue Streak (Conneaut Lake)   Conneaut Lake Park     Closed
# 167      Big Thunder Mountain Railroad                Other        NaN
# 237  Thunder Run (Canada's Wonderland)  Canada's Wonderland  Operating
#
#                                           Manufacturer  Year_Introduced  \
# 43                                  Traver Engineering             1927
# 60                                      Fred W. Pearce             1937
# 61                                                 NaN             1938
# 167  Arrow Development (California and Florida)Dyna...             1980
# 237                                         Mack Rides             1986
#
#      Latitude  Longitude Type_Main Opening_Date  Speed_Mph  Height_Ft  \
# ...

# %%
# Checking an example duplicate
df.query('Coaster_Name == "Crystal Beach Cyclone"')
# Out:
#              Coaster_Name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     Year_Introduced  Latitude  Longitude Type_Main Opening_Date  Speed_Mph  \
# 39             1926   42.8617   -79.0598      Wood   1926-01-01       60.0
# 43             1927   42.8617   -79.0598      Wood   1926-01-01       60.0
#
#     Height_Ft  Inversions  Gforce
# 39        NaN           0     4.0
# 43        NaN           0     4.0

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Status', 'Manufacturer', 'Year_Introduced',
#        'Latitude', 'Longitude', 'Type_Main', 'Opening_Date', 'Speed_Mph',
#        'Height_Ft', 'Inversions', 'Gforce'],
#       dtype='object')

# %%
df = df.loc[~df.duplicated(subset = ['Coaster_Name','Location', 'Opening_Date'])].reset_index(drop=True).copy()

# %% [markdown]
# The code `df.loc[~df.duplicated(subset=['Coaster_Name', 'Location', 'Opening_Date'])].reset_index(drop=True)` performs the following operations:
#
# 1. `df.duplicated(subset=['Coaster_Name', 'Location', 'Opening_Date'])` checks for duplicate rows in the DataFrame `df` based on the specified subset of columns, which in this case are 'Coaster_Name', 'Location', and 'Opening_Date'. The `duplicated()` function returns a boolean Series where True represents duplicate rows and False represents non-duplicate rows.
#
# 2. `~df.duplicated(subset=['Coaster_Name', 'Location', 'Opening_Date'])` uses the negation operator (~) to invert the boolean values in the Series. This will give us a Series where True represents non-duplicate rows and False represents duplicate rows. The tilde (~) operator is used to negate the values in the Series.
#
# 3. `df.loc[~df.duplicated(subset=['Coaster_Name', 'Location', 'Opening_Date'])]` selects the rows from the DataFrame `df` where the corresponding values in the Series are True. In other words, it filters out the duplicate rows and keeps only the non-duplicate rows.
#
# 4. `reset_index(drop=True)` resets the index of the resulting DataFrame. The `drop=True` parameter ensures that the old index is not added as a new column in the DataFrame.
#
# Overall, this code snippet removes duplicate rows from the DataFrame based on the specified subset of columns ('Coaster_Name', 'Location', 'Opening_Date'), and returns a new DataFrame with only the non-duplicate rows.

# %%
df.shape
# Out:
# (990, 13)

# %% [markdown]
# ## Step 3: Feature Understanding
#
# (Univariate analysis)
#
# - Plotting Feature Distributions
# - Histogram
# - KDE
# - Boxplot

# %%
df['Year_Introduced'].value_counts()
# Out:
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1956     1
# 1959     1
# 1961     1
# 1895     1
# 1884     1
# Name: Year_Introduced, Length: 101, dtype: int64

# %%
sns.histplot(data = df['Year_Introduced'], color = 'blue').set(title = 'Histogram of the Coasters Year Introduced');

# %%
ax = df['Year_Introduced'].value_counts().head(10).plot(kind = 'barh', title = 'Top 10 Years Coasters Introduced', color = 'brown', alpha = 0.7)
ax.set_xlabel('Year Introduced')
ax.set_ylabel('Count');

# %%
sorted_counts = df['Year_Introduced'].value_counts().head(10).sort_values(ascending=True)
sorted_counts
# Out:
# 2013    23
# 2011    24
# 2007    24
# 2004    25
# 2008    27
# 2002    28
# 2001    29
# 1998    30
# 2000    45
# 1999    46
# Name: Year_Introduced, dtype: int64

# %%
sns.barplot(x=sorted_counts, y=sorted_counts.index, orient='horizontal', color='lightblue').set(title='Top 10 Years Coasters Introduced');

# %%
sns.histplot(data = df['Speed_Mph'], bins = 20, color = 'blue', kde = True).set(title = 'Coaster Speed (mph)');

# %%
type_main_data = df['Type_Main'].value_counts()

# %%
sns.barplot(x=type_main_data.index, y=type_main_data.values).set(title='Distribution of Coaster Types', xlabel = 'Coaster Type', ylabel='Count');

# %% [markdown]
# ## Step 4: Feature Relationships
# (multivariate analysis)
#
# - Scatterplot
# - Heatmap Correlation
# - Pairplot
# - Groupby comparisons

# %%
custom_palette = sns.color_palette("mako_r", as_cmap=True)
sns.scatterplot(x='Speed_Mph', y='Height_Ft', data=df, s=150, hue='Year_Introduced', palette=custom_palette)
plt.title('Coaster Speed vs Height');

# %%
sns.pairplot(data= df, vars=['Year_Introduced','Speed_Mph','Height_Ft','Inversions','Gforce'], hue='Type_Main');

# %%
# Get correlation data
corr = df[['Year_Introduced','Speed_Mph','Height_Ft','Inversions','Gforce']].dropna().corr()
corr_matrix = corr.iloc[1:,:-1]
corr_matrix
# Out:
#             Year_Introduced  Speed_Mph  Height_Ft  Inversions
# Speed_Mph          0.171978   1.000000   0.733999   -0.028705
# Height_Ft          0.135413   0.733999   1.000000   -0.079736
# Inversions        -0.209887  -0.028705  -0.079736    1.000000
# Gforce             0.160247   0.607383   0.466482    0.275991

# %%
# ones_like can build a matrix of booleans (True,False) with the same shape as data
ones = np.ones_like(corr, dtype=bool)
ones
# Out:
# array([[ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True]])

# %%
# np's triu: return only triangle matrix
mask = np.triu(ones)
adjust_mask = mask[1:,:-1]
adjust_mask
# Out:
# array([[False,  True,  True,  True],
#        [False, False,  True,  True],
#        [False, False, False,  True],
#        [False, False, False, False]])

# %%
sns.heatmap(corr_matrix, cmap = 'Blues', annot= True, mask = adjust_mask)
# Out:
# <Axes: >

# %% [markdown]
# ## Step 5: Ask a Question about the data¶
# Try to answer a question you have about the data using a plot or statistic.
#
# **"What are the locations with the fastest roller coasters (minimum of 10)?"**

# %%
groupby = df.query("Location != 'Other'") \
            .groupby('Location')['Speed_Mph'] \
            .agg(['mean','count']) \
            .query('count >= 10') \
            .sort_values('mean', ascending=False)
groupby
# Out:
#                                  mean  count
# Location
# Busch Gardens Williamsburg  58.318182     11
# Cedar Point                 57.833333     18
# Six Flags Magic Mountain    57.241176     17
# Canada's Wonderland         53.533333     12
# Six Flags Great Adventure   53.036364     11
# Kings Dominion              52.083333     12
# Hersheypark                 50.576923     13
# Kings Island                49.273684     19
# Carowinds                   43.571429     14
# Alton Towers                42.791667     12

# %%
sns.barplot(x='mean', y=groupby.index, data=groupby, color = "brown")
plt.xlabel('Mean Speed (mph)')
plt.ylabel('Location')
plt.title('Mean Speed of Coasters by Location');
